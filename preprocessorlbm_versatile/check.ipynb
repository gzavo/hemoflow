# %%
import numpy as np

# %%
voxels = np.load("voxels.npy", allow_pickle=True)

# %%
voxels
# Out:
# array([[ 1, 14, 92],
#        [ 1, 14, 93],
#        [ 1, 14, 94],
#        [ 1, 14, 92],
#        [ 1, 15, 92],
#        [ 1, 16, 92],
#        [ 1, 16, 94],
#        [ 1, 17, 93],
#        [ 1, 14, 94],
#        [ 2, 16, 94],
#        [ 3, 37, 16],
#        [ 3, 37, 17],
#        [ 3, 37, 18],
#        [ 2, 15, 94],
#        [ 2, 16, 94],
#        [ 3, 37, 16],
#        [ 3, 37, 16],
#        [ 4, 37, 19],
#        [ 4, 37, 16],
#        [ 4, 37, 16],
#        [ 4, 37, 19],
#        [ 5, 37, 16],
#        [ 5, 37, 16],
#        [ 6, 37, 20],
#        [ 5, 37, 16],
#        [ 6, 37, 20],
#        [ 7, 37, 40],
#        [ 7, 37, 41],
#        [ 7, 37, 17],
#        [ 8, 37, 37],
#        [ 8, 37, 38],
#        [ 8, 37, 39],
#        [ 8, 37, 42],
#        [ 8, 37, 43],
#        [ 8, 37, 44],
#        [ 8, 37, 45],
#        [ 8, 37, 46],
#        [ 8, 37, 47],
#        [ 8, 37, 48],
#        [ 9,  1,  4],
#        [ 9,  1,  5],
#        [ 9,  1,  6],
#        [ 9,  1,  7],
# ...

# %%
np.isnan(voxels).any()
# Out:
# False
